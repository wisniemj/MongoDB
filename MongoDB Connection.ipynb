# %% [markdown]
# # Introduction, package import, data import

# %% [markdown]
# Import MongoClient from pymongo in order to connect to a MongoDB client
# Additionally, import pandas as in this example we do not have a mongo client to connect to, but we will show the syntax to connect to a hypothetical DB.
#
# I will use a .csv file I will import for the actual array in place of a MongoDB connection

# %%
# Import necessary packages
import pandas as pd
from pymongo import MongoClient
import os

# %%
# Create your connection to the Mongo Client -- we will assume this has the array of data we want
client = MongoClient()

# %%
# Import array from Mongo -- once again, only as an example to show how to connect to Mongo
word_docs = client.word_docs

# %%
# Pinpoint the database name collection name for the word_docs database
word_docs_data = word_docs.collection_name

# %%
# Create the dataframe for the word_docs -- this will be empty
word_docs_df = pd.DataFrame(list(word_docs_data.find()))

# %% [markdown]
# At this point in the code, the data from a MongoDB would have been imported and constructed into a pandas dataframe.  I used pandas and python for anything DB, array, dataframe, etc. related because I've found python and pandas to be the most user friendly and easiest to use.  Pandas was actually built to provide its users an excel-esque experience.

# %%
# Set our directory to read in our example dataframe
default_directory = os.getcwd()

# %%
# Import word_docs .csv -- bring in every column as an object, we will change the Datetime to Datetime in a bit
word_docs = pd.read_csv(default_directory + '/word_docs.csv', dtype=object)

# %%
#View data to verify we have the right data set
word_docs
# Out:
#               Datetime      Document1       Document2        Document3  \
# 0        1/6/2018 0:00        ramneek      rarenesses       Ranunculus
# 1        1/6/2018 0:00       ranching           ramed     raspberriade
# 2        1/6/2018 0:01      rapacious        ramblers       ratcatcher
# 3        1/6/2018 0:01    raveinelike     rathnakumar          rassled
# 4        1/6/2018 0:02         raunge           Raouf     rationalizer
# 5        1/6/2018 0:02          rally          randan             rale
# 6        1/6/2018 0:03   razor-billed          raspis          rastled
# 7        1/6/2018 0:03        raucous          raukle         Rancagua
# 8        1/6/2018 0:04       rampancy         rassled           raphis
# 9        1/6/2018 0:04    rallymaster       raunchier       rationably
# 10       1/6/2018 0:05        ramstam       rare-felt           Ranger
# 11       1/6/2018 0:05      rantepole          rasant        rataplans
# 12       1/6/2018 0:06       raticide       rattlings    raven-tressed
# 13       1/6/2018 0:06  rapid-passing        randomly         ravelers
# 14       1/6/2018 0:07        Randell         rampole        rake-hell
# 15       1/6/2018 0:07          Ranna           Rasht           rawish
# 16       1/6/2018 0:08       Rasputin          ratans           raukle
# 17       1/6/2018 0:08          ramet         Rauraci           rawish
# 18       1/6/2018 0:09      Raskolnik         rangler    rat-kangaroos
# 19       1/6/2018 0:09       rawbones        ramicorn        ratfishes
# 20       1/6/2018 0:10        rattish        Rawlplug           rattle
# 21       1/6/2018 0:10   ramentaceous         rankled           ranine
# 22       1/6/2018 0:11        ramplor  ramshackleness            ram's
# 23       1/6/2018 0:11        rattler          rajeev            Rasht
# 24       1/6/2018 0:12       ranchers           Rashi          raucity
# 25       1/6/2018 0:12       rakingly           rared     ravenousness
# 26       1/6/2018 0:13       Ramayana            rara  rancidification
# 27       1/6/2018 0:13         ramesh    ramentaceous          rattrap
# 28       1/6/2018 0:14        Rapidan            rall    rattleskulled
# 29       1/6/2018 0:14         rasion          ramson            Ratha
# ...                ...            ...             ...              ...
# 22591  1/13/2018 20:15    rampantness          ramjet        Ravendale
# 22592  1/13/2018 20:16       rakehell         rambler        Raphaelle
# 22593  1/13/2018 20:16         rances          raster        rampantly
# 22594  1/13/2018 20:17       ranksmen        ratement          rampick
# 22595  1/13/2018 20:17      rapparees        Ramsdell         raveners
# 22596  1/13/2018 20:18          Ramey          Raysal              RAO
# 22597  1/13/2018 20:18        rankled         Rankine        randomize
# 22598  1/13/2018 20:19          ratel      ramiparous         ratlines
# 22599  1/13/2018 20:19        Randall           Ramah      raveinelike
# 22600  1/13/2018 20:20       ravishes        rancours      ratatouille
# 22601  1/13/2018 20:20         ratine          rasher         rareties
# 22602  1/13/2018 20:21        rashest       ratchment          Rasores
# 22603  1/13/2018 20:21        Ranales           rared         raspiest
# 22604  1/13/2018 20:22       rational          rasing          Ravenna
# 22605  1/13/2018 20:22      Rathauser     rattleproof    rat-kangaroos
# 22606  1/13/2018 20:23       rajaship         ratting          rangpur
# 22607  1/13/2018 20:23       rateless     rangefinder        rarifying
# 22608  1/13/2018 20:24      Rajasthan          Ravens           ratton
# 22609  1/13/2018 20:24          Ramee        rashlike           Randal
# 22610  1/13/2018 20:25         ramies          Ramses          randoms
# 22611  1/13/2018 20:25          ram's       rapeseeds    rank-swelling
# 22612  1/13/2018 20:26         rapido            rath           rambla
# 22613  1/13/2018 20:26      rattlings      rake-teeth          ravings
# 22614  1/13/2018 20:27     rangeheads         rangale     ranunculuses
# 22615  1/13/2018 20:27         rasher        ratanies        rare-seen
# 22616  1/13/2018 20:28         ramees     Raphiolepis           rajahs
# 22617  1/13/2018 20:28        rapiner         rajpoot            rater
# 22618  1/13/2018 20:29        raploch           ramal            ramal
# 22619  1/13/2018 20:29       Rashomon       ramparted     rattleheaded
# 22620  1/13/2018 20:30      ranchlike          rappel       rapid-fire
#
#            Document4         Document5       Document6      Document7  \
# 0             rander          raisings          ramees   rank-brained
# 1           ranstead            Ravana            RAND    raspatorium
# 2             raping          ravishes        rareness   rat-deserted
# 3           ranarium           rattail     rascalities   ravenousness
# 4           rattraps           rameous        ranching        raisine
# 5          rancheros          Ramoosii      raree-show      rapparees
# 6           rankings     rationalistic         ratafia   rare-painted
# 7             raphae         ranchland       Ramillied     ransomable
# 8             ratios           rammass          rajeev  rationalistic
# 9              Rakia            Rallus  ranunculaceous        randing
# 10        raw-headed         rapturing   rationalising        rappers
# 11        rattle-top           Rapidan           rands       ratching
# 12             rasen           rasceta        ratteens   rakishnesses
# 13       raspberries          ransomer           Ranee        Ramberg
# 14           randier             Ramah           ramus        raphide
# 15        rationable  rapture-bursting           raked       Rangifer
# 16          Raytheon            randan          Ramwat      Ramillied
# 17              RAND           raucous        Rajewski     randomwise
# 18     ramosopalmate            rarest     rationalism     rampancies
# 19           Raquela      rapid-firing         Ranitta         Rasure
# 20            rancel          ravingly          Ramist        Raurich
# 21            rapter             rawky            rall        ratwood
# 22            ravine            Ranjiv          raises       Ranburne
# 23       raucousness             Ravia          Ramman      ramuscule
# 24            rattly             rapes          rambeh        rattled
# 25           rashest              Rama           raper         Ravena
# 26              rauk      razor-billed      Rajasthani          ranks
# 27           raphide             rases       rattingly          ratan
# 28             razes           Rashida         Rameses       rambutan
# 29            ratton           rapeful           rangy        rattage
# ...              ...               ...             ...            ...
# 22591  rapturousness             Razid       rapture's           Rask
# 22592         Rajkot      rank-growing         rariora         rasour
# 22593       ratholes        Ravenswood          Rankin        rastled
# 22594     randomized          rankling       ransomers            raw
# 22595         rapper           rashing        ramilies   rataplanning
# 22596    rash-levied           ranular          Ranchi         Ralina
# 22597        ratites             raped     rapier-like     Rawalpindi
# 22598      rattlenut         rangeland           Randi     Ravensdale
# 22599   Raphaelesque            RATFOR           rappe         ranids
# 22600       Raptores           ramular          Rampur         Ravens
# 22601     rascallion            rasant       ransomers     Raskolniki
# 22602       rampager           Raphael  rantum-scantum         Rawdan
# 22603       ratement          Ravenala         ranches         Ranina
# 22604           rant            ramtil      ratcatcher       Ramessid
# 22605    raw-striped              raob     rationalism          ratio
# 22606     Ramistical           ratfink          rasing          ratti
# 22607         Randia           randori          rarest       ravehook
# 22608       ravaging         Rasmussen          Rambam        rattled
# 22609         Ravens           Ransell       ravindran  randomization
# 22610         random              rats         ratters        Rappite
# 22611       ranchman            Rasure        ravening        ratafia
# 22612     razor-bill        ramparting        ranching          Raman
# 22613   rat-infested     rationalizing         Rapanea        ravelly
# 22614      ramifying              rauk             rax          rakan
# 22615    rattle-head           Ranzini            Rama      rancelmen
# 22616    Raphidiidae           Ranella           ramex          razoo
# 22617     raveningly      rationalised    rate-cutting          Ratha
# 22618  ramosopalmate         ravellers       Ravensara    rataplanned
# 22619     Raphaelite         ranselman        raisonne          ramed
# 22620     ravelproof           ramilie           rales       Ramesses
#
#              Document8       Document9     Document10       Document11  \
# 0                Ranee         rambler   rationalized        rancherie
# 1            rampingly        ramequin        Rancell          ranpike
# 2                raver           raked          ratal          rancour
# 3               rakers         rammers         randem          rappees
# 4           Ravenswood          Rawdon    rationalise      raw-colored
# 5             Rastaban  rampageousness          raspy        rawnesses
# 6            ratifiers          ramiro     rawishness          raisine
# 7                ravin      rangelands        Rambort      ratatouille
# 8      raven-feathered         ratbite          RARDE          Randers
# 9             Rajewski           raxed         rashes          Ramberg
# 10              Ramean         rashers         ramsch   rash-thoughted
# 11             rattler          rasers            rax        rat-gnawn
# 12              Rambam       ratheripe       ramiform         rattraps
# 13         ramisectomy         Ranitta        Ransell       ranivorous
# 14       rattlety-bang          ratten     Raphaelite            Raton
# 15               Ralli           Raton         rancid     raven-haired
# 16             ramtils             RAM           rang         rapports
# 17              ratels         rajasic      rappeling           ratite
# 18           razorback       rascality     ravellings           raspis
# 19           ratifiers       ranginess       Ramillie           rameal
# 20              ranjit        ramilies   Ramphastidae           ratted
# 21              rapper        raveners       rarefies        rancherie
# 22             ravison          Rajput         ratine           Ranice
# 23          ramblingly         rathely     Ramistical            raser
# 24             rathite     rationalize      ravenling         ramiform
# 25              Rangel         ramilie    rattleskull           Raquel
# 26             rathest       ravissant       Ramstein        Raskolnik
# 27             rakeage       rascaldom   rarefactions          ramping
# 28              Rakata       ramuscule        raisers           ranged
# 29             ravison   ratiocinators        rariety       rancescent
# ...                ...             ...            ...              ...
# 22591         ravining          ratals         ranees      rank-winged
# 22592        ramuscule      Randallite        ratfish       ratepaying
# 22593         Raphanus        ramental         rapids       rarefiable
# 22594         Rayshell        Rallidae  rattlety-bang     rat-stripper
# 22595  ratificationist       randomish           RARP      rattlebones
# 22596          ramplor  rank-and-filer            RAM       Ravencliff
# 22597     razor-billed         raspier     raven-torn          ramhood
# 22598            rases     rapidamente   rat-infested    raven-tressed
# 22599           rammel      randomizer           raob       ramigerous
# 22600            rajas        rancours      Ravenelia         ratitous
# 22601       raptnesses        rattraps     rat-tattle             RAVC
# 22602          Ravinia            rats         Raseda           rapids
# 22603       raw-ribbed      rationless        raveled          Rapanea
# 22604          raising     raucousness       ratlines          ramanas
# 22605          rameous          Ravana        rapines      rakehellish
# 22606          Raoulia    rarefication        Raskind         Ramstein
# 22607         rarified       ratooners       ravishes  rancidification
# 22608      rattleskull    rampageously          ratti      rat-tat-tat
# 22609    raspberry-jam          ramble         Ramism            Rasia
# 22610         rascalry        raphides        ramenta      rare-shaped
# 22611        rat-tight            Raji     rakishness     rank-growing
# 22612          Ranique   ratiocinators     ramfeezled         rangeman
# 22613    Rauschenbusch  rank-and-filer         Ranchi          rave-up
# 22614           Rambow    Ramphastides        Rantoul          raisers
# 22615        rammishly    rampageously         razees           rakish
# 22616       Rawalpindi       rangeland    rank-minded           rapter
# 22617            ratel      randomness        rations   rampageousness
# 22618          rarebit         raughty       Ranburne        rampaging
# 22619         Ranburne     rapaciously          rap's          rathole
# 22620          ramekin         raughty     Raphidodea        Ramillies
#
#            Document12     Document13        Document14        Document15
# 0            raisings       raw-wool           rattier            ravine
# 1          rangelands         rakhal         razorback      rationalized
# 2           rambutans         raises            rattly        rat's-tail
# 3                rake  ramentiferous       rare-shaped          Randolph
# 4            rascasse       ravine's           Ranidae          Randlett
# 5               raupo       ranchman         rapturist         rattlebox
# 6            rarified         Ramist         raunchier          rakishly
# 7             Ramburt       Rauscher          ratanhia            Ramism
# 8               Ranee        rantock       rancidified   rapaciousnesses
# 9            rarefied     rash-brain          rawhides         Rajputana
# 10              rammi         Rameau         Rajputana           ranular
# 11        rattlemouse          rally        ramiparous     raucousnesses
# 12            ratlike          Rajab           ranchos       raspatorium
# 13          Ramillied       ransacks           rattler         ratfishes
# 14            Ramburt        Rashida          Ramayana               RAS
# 15              rally   ramuliferous            ratios           Ramadan
# 16             ratels     ramshackle            Raseta         Ravendale
# 17         Ravencliff  raucousnesses           rathely     rarefactional
# 18               Ravo        Ranidae          Ranzania             Ramah
# 19             Rashti     ransacking             razoo          rajarshi
# 20            rankish         rancel          ransomer           rauriki
# 21          rapturous         raisin  rattlesnake-bite          rancored
# 22             razeed     rapid-fire          rapparee            raters
# 23            Ramberg         Rambam     rat-inhabited          rammiest
# 24            ramenta        rattens       ramgunshoch        rallycross
# 25             rawnie      Raphaelic           Ravenna          rallyist
# 26           ratsbane   rapateaceous        rattlebush           rattery
# 27          raw-faced      rawnesses           ratches           rantize
# 28       rash-running       Ramadoux             rat's            rassle
# 29         raveningly       rasamala              rale               Rap
# ...               ...            ...               ...               ...
# 22591        rawhided        rankers         ranchless       rank-winged
# 22592          raphus        rattery           rangale        rancescent
# 22593           razoo        ravaged       randomizing          Rashidov
# 22594       rare-seen         rancel             Ranee             rased
# 22595          rakely      ravenlike             ratti             ramex
# 22596          rattel       ramified         rakehells            rasour
# 22597       rationing       rapakivi         ramuscule            rakers
# 22598          rawish      rampaging     raven-colored              Raji
# 22599           razoo        rathest           ratteen             rapid
# 22600      rampallion        raspish         rapturous  ramososubdivided
# 22601         Rangoon        Randell             Raton          ratified
# 22602        ramforce         ramjet            ratten            rammed
# 22603          ratton      ratheness          rattails              RASC
# 22604  rambunctiously   rare-painted            rangey       rancidified
# 22605          Rausch       ratement            raking        range-bred
# 22606            raun        ratfish   rancidification            ranted
# 22607    rat-infested       ratooned      ratiocinated         rapturous
# 22608        ravaging        Ranchod           rammage         ranchlike
# 22609           rat's        Rauraci           ramsons            Rashti
# 22610         ravings         rarity          ratifies           rashing
# 22611        Ralfston         Ranson        ratability          raw-head
# 22612       rapparees         Ramada          ramparts            Rawdon
# 22613          ramees      raw-nosed         ralliform        ramparting
# 22614      Raphidodea         rattle           Ralston            rassle
# 22615      rappelling    Raphiolepis         rakesteel          rampancy
# 22616       rascalism          ratal           rattler      rash-running
# 22617        ratproof        rapping           Rapelje            ramous
# 22618         ramhood         rancid          raisonne         rapturize
# 22619       raunchier          rajes       ratatouille              rall
# 22620        rattaree         rateen   rapture-smitten             Razid
#
# [22621 rows x 16 columns]

# %% [markdown]
# # Most Frequent Word

# %% [markdown]
# Our first piece of analysis is to find the word that occurs the most frequently within this dataset.  My immediate reaction would be to unpivot my dataset.  Because this analysis is document independent, we can safely "stack" or unpivot this dataset so each word is within a single column

# %%
# Unpivot dataset
word_docs_melt = pd.melt(word_docs, #my dataframe
                         id_vars=['Datetime'], #what to keep my y-axis as
                         value_vars = list(word_docs.loc[:, word_docs.columns != 'Datetime'].columns), #the list of columns that we want to unpivot (all columns except Datetime is what the code is saying)
                         var_name = 'Document',
                         value_name = 'Word')

# %%
# Group by word and count occurrence of each word.  Sort highest to lowest
word_docs_melt.groupby('Word')[['Word']].count().sort_values(by='Word', ascending=[0]).iloc[0]
# Out:
# Word    261
# Name: Ravenelia, dtype: int64

# %% [markdown]
# # 24 hour Period Analysis

# %% [markdown]
# Our next piece of analysis is to identify the most common word within the last 24 hours.  We will use the previous stacked data set that we created above for this analysis as it is Document independent

# %%
# Our first step to to convert our datetime field into an actual datetime datatype
word_docs_melt['Datetime'] = pd.to_datetime(word_docs_melt['Datetime'], yearfirst=True)

# %%
# We are going to do the same exact groupby as we did in our first analysis, except we will add an additional conditional: last 24 hours
word_docs_melt[word_docs_melt['Datetime'] >= '1/13/2018'].groupby('Word')[['Word']].count().sort_values(by='Word', ascending=[0]).iloc[0]
# Out:
# Word    40
# Name: ramex, dtype: int64

# %% [markdown]
# # Trend Analysis

# %% [markdown]
# Our final piece of analysis is to do a 24 hour period over previous 24 hour period for highest growth in appearance.  We will create two datasets, a 24 hour period and a previous 24 hour period dataset, join on the word column and ELIMINATE any words that don't have a match (i.e. they appeared in one period by not the other -- this is meaningless as the growth would be 0 or infinite)

# %%
# Create the past 24 hour period dataframe
Cur_Period = word_docs_melt[word_docs_melt['Datetime'] >= '1/13/2018'].groupby('Word')[['Word']].count()

# %%
# Create the past 24 hour period dataframe
Prev_Period = word_docs_melt[(word_docs_melt['Datetime'] >= '1/12/2018')
                           & (word_docs_melt['Datetime'] < '1/13/2018')].groupby('Word')[['Word']].count()

# %%
# We are now going to rename the "Word" column of both datasets to "Word_Count" and reset our index so we can join both datasets
Cur_Period = Cur_Period.rename(columns = {'Word' : 'Word_Count',}).reset_index(drop=False)

Prev_Period = Prev_Period.rename(columns = {'Word' : 'Word_Count',}).reset_index(drop=False)

# %%
# Merge both datasets -- keep in mind the Word_Count will have an _x and _y variant, representing the left and right tables respectively
merge = pd.merge(Cur_Period, #left table
                 Prev_Period, #right table
                 on=['Word'])

# %%
# We now perform an Period over Period analysis to see highest growth
merge['PoP%'] = merge['Word_Count_x'] / merge['Word_Count_y']

# %%
# Sort our dataset and find the word that increased the most
merge.sort_values(by = 'PoP%', ascending=0).iloc[0]
# Out:
# Word              ramed
# Word_Count_x         20
# Word_Count_y          7
# PoP%            2.85714
# Name: 473, dtype: object

# %% [markdown]
# In conclusion, "ramed" increased in appearance between the current 24 hour period over the previous 24 hour period by 286%
